# %% [markdown]
# <a href="https://colab.research.google.com/github/MhdRaihanB/ML_Tasks_MhdRaihanB/blob/main/5thWeekTasks/EDA%20IT%20Salary%202020_Muhammad%20Raihan%20Butar-Butar_1103213077.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama : Muhammad Raihan Butar-Butar
#
# NIM : 1103213077
#
# Tugas Lecture 5 EDA IT Salary
#
# Dataset: IT Salary Survey EU 2020.csv
#
# Dokumentasi ChatGPT : https://chat.openai.com/share/09017014-ed89-4b8a-9593-015c3ea810e1

# %% [markdown]
# # MOUNT GOOGLE DRIVE

# %%
from google.colab import drive

# Menghubungkan dengan Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # IMPORT LIBRARY

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# # MEMBACA DATASET
# Prompt : berikan kode untuk membuat dataframe dari file csv dengan nama file IT Salary Survey EU 2020.csv yang berada di folder Dataset pada google drive pribadi di google colab setelah mount dengan drive

# %%
csv_file_path = '/content/drive/My Drive/Dataset/IT Salary Survey EU 2020.csv'

# Load CSV into a DataFrame
df = pd.read_csv(csv_file_path)

# Display the first few rows of the DataFrame
df.head()
# Out:
#              Timestamp   Age Gender    City           Position   \
# 0  24/11/2020 11:14:15  26.0   Male  Munich   Software Engineer
# 1  24/11/2020 11:14:16  26.0   Male  Berlin   Backend Developer
# 2  24/11/2020 11:14:21  29.0   Male  Berlin   Software Engineer
# 3  24/11/2020 11:15:24  28.0   Male  Berlin  Frontend Developer
# 4  24/11/2020 11:15:46  37.0   Male  Berlin   Backend Developer
#
#   Total years of experience Years of experience in Germany Seniority level  \
# 0                         5                              3          Senior
# 1                         7                              4          Senior
# 2                        12                              6            Lead
# 3                         4                              1          Junior
# 4                        17                              6          Senior
#
#   Your main technology / programming language  \
# 0                                  TypeScript
# ...

# %% [markdown]
# # MEMBERSIHKAN DATASET
# Prompt : beri kode untuk mengubah nilai null dari dataframe saya, jika tipe data float ubah menjadi 0 dan jika tipe data non numeric menjadi "-"

# %%
# Fungsi untuk mengubah nilai null
def replace_null(value):
    if pd.isnull(value):
        if isinstance(value, float):
            return 0
        else:
            return "-"
    return value

# Menggunakan applymap untuk menerapkan fungsi ke setiap elemen dalam dataframe
df = df.applymap(replace_null)

df.head()
# Out:
#              Timestamp   Age Gender    City           Position   \
# 0  24/11/2020 11:14:15  26.0   Male  Munich   Software Engineer
# 1  24/11/2020 11:14:16  26.0   Male  Berlin   Backend Developer
# 2  24/11/2020 11:14:21  29.0   Male  Berlin   Software Engineer
# 3  24/11/2020 11:15:24  28.0   Male  Berlin  Frontend Developer
# 4  24/11/2020 11:15:46  37.0   Male  Berlin   Backend Developer
#
#   Total years of experience Years of experience in Germany Seniority level  \
# 0                         5                              3          Senior
# 1                         7                              4          Senior
# 2                        12                              6            Lead
# 3                         4                              1          Junior
# 4                        17                              6          Senior
#
#   Your main technology / programming language  \
# 0                                  TypeScript
# ...

# %% [markdown]
# # VISUALISASI DATA
#
# Prompt : berikan kode untuk melakukan visualisasi masing-masing data numerik dengan histogram

# %%
for column in df.select_dtypes(include='number').columns:
    plt.figure(figsize=(8, 6))
    plt.hist(df[column].dropna(), bins=10, color='skyblue', edgecolor='black')
    plt.title(f'Histogram of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.grid(True)
    plt.show()

# %% [markdown]
# # DETEKSI OUTLIER
# Prompt : berikan kode untuk melakukan deteksi outlier pada kolom Age pada dataframe IT Salary Survey EU 2020.csv lalu tampilkan visualisasinya menggunakan scatter plot dengan membandingkannya dengan kolom Yearly Brutto Salary

# %%
# Menghitung IQR pada kolom Age
Q1_age = df['Age'].quantile(0.25)
Q3_age = df['Age'].quantile(0.75)
IQR_age = Q3_age - Q1_age

# Menentukan batas bawah dan batas atas untuk outlier
lower_bound_age = Q1_age - 1.5 * IQR_age
upper_bound_age = Q3_age + 1.5 * IQR_age

# Mendeteksi outlier
outliers_age = df[(df['Age'] < lower_bound_age) | (df['Age'] > upper_bound_age)]

# Visualisasi outlier dengan scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(df['Age'], df['Yearly brutto salary (without bonus and stocks) in EUR'], c='blue', label='Data')
plt.scatter(outliers_age['Age'], outliers_age['Yearly brutto salary (without bonus and stocks) in EUR'], c='red', label='Outliers')
plt.title('Scatter Plot of Age vs Yearly Brutto Salary with Outliers')
plt.xlabel('Yearly brutto salary (without bonus and stocks) in EUR')
plt.ylabel('Age')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # ANALISIS KORELASI
# Prompt : berikan kode untuk melakukan analisis korelasi dengan hanya menggunakan data yang bersifat numerik

# %%
# Pilih hanya kolom-kolom yang bersifat numerik
numeric_df = df.select_dtypes(include=['int64', 'float64'])

# Melakukan analisis korelasi
correlation_matrix = numeric_df.corr()

# Tampilkan matriks korelasi
print("Correlation Matrix:")
print(correlation_matrix)

# Visualisasi matriks korelasi dengan heatmap
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix')
plt.show()
# Out:
# Correlation Matrix:
#                                                          Age  \
# Age                                                 1.000000
# Yearly brutto salary (without bonus and stocks)... -0.122791
# Annual brutto salary (without bonus and stocks)... -0.010265
# Have you been forced to have a shorter working ...  0.014060
#
#                                                     Yearly brutto salary (without bonus and stocks) in EUR  \
# Age                                                                                         -0.122791
# Yearly brutto salary (without bonus and stocks)...                                           1.000000
# Annual brutto salary (without bonus and stocks)...                                           0.004105
# Have you been forced to have a shorter working ...                                          -0.010730
#
# ...

# %% [markdown]
# # ANALISIS DISTRIBUSI KELAS
# Prompt : bagaimana cara saya melakukan analisis distribusi kelas?

# %%
# Analisis distribusi kelas
kelas_distribution = df['Yearly brutto salary (without bonus and stocks) in EUR'].value_counts()

# Tampilkan distribusi kelas
print("Distribusi Kelas:")
print(kelas_distribution)

# Visualisasi distribusi kelas dengan bar plot
plt.figure(figsize=(8, 6))
kelas_distribution.plot(kind='bar', color='skyblue')
plt.title('Distribution of Classes')
plt.xlabel('Class')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()
# Out:
# Distribusi Kelas:
# Yearly brutto salary (without bonus and stocks) in EUR
# 6.000000e+04    85
# 7.000000e+04    83
# 6.500000e+04    77
# 7.500000e+04    73
# 8.000000e+04    66
#                 ..
# 1.000000e+11     1
# 3.400000e+04     1
# 7.930000e+04     1
# 6.630000e+04     1
# 3.835000e+04     1
# Name: count, Length: 201, dtype: int64

# %% [markdown]
# # ANALISIS TIME SERIES

# %% [markdown]
# Dikarenakan dataset tidak memiliki data berurutan dalam interval tertentu, maka tidak memungkinkan untuk melakukan analisis time series menggunakan dataset ini.
